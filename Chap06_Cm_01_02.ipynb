# %% [markdown]
# <a href="https://colab.research.google.com/github/katsukiyamamoto/EU_M_Math/blob/main/Chap06_Cm_01_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6-1-1

import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
#6-2-1

hier_df = DataFrame(
    np.arange(9).reshape(3,3),
    index = [
        ['a','a','b'],
        [1,2,2]
    ],
    columns=[
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.index.names=['key1','key2']

hier_df.columns.names=['city','color']
hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
#6-2-1-1

hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
#6-2-1-2

hier_df.groupby(level='key2',axis=0).sum()
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
hier_df.groupby(level='color',axis=1).sum()
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    3
#      2        3    9
# b    2        6   15

# %%
#6-2-1-3

hier_df.drop(['b'])
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5

# %%
#6-2-2

data1 = {
    'id': ['100','101','102','103','104','106','108','110','111','113'],
    'city': ['Tokyo','Osaka','Kyoto','Hokkaido','Tpkyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year': [1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name': ['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df1 = DataFrame(data1)
df1
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tpkyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo

# %%
data2 = {
    'id': ['100','101','102','105','107'],
    'math': [50,43,33,76,98],
    'english': [90,30,20,50,30],
    'sex' : ['M','F','F','M','M'],
    'index_num': [0,1,2,3,4]
}
df2 = DataFrame(data2)
df2
# Out:
#     id  math  english sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
#6-2-2-2

print('結合テーブル')
pd.merge(df1,df2,on='id')
# Out:
# 結合テーブル
#     id   city  birth_year     name  math  english sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
#6-2-2-3

pd.merge(df1,df2,how='outer')
# Out:
#      id      city  birth_year     name  math  english  sex  index_num
# 0   100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tpkyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5   106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6   108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8   111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9   113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 10  105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 11  107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
pd.merge(df1,df2, left_index=True, right_on='index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  english sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tpkyo        1982   Steeve  107    98       30   M          4

# %%
#6-2-2-4

pd.merge(df1,df2,how='left')
# Out:
#     id      city  birth_year     name  math  english  sex  index_num
# 0  100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1  101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2  102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3  103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4  104     Tpkyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5  106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6  108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7  110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
#6-2-2-5

data3 = {
    'id': ['117','118','119','120','125'],
    'city': ['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year' : [1990,1989,1992,1997,1982],
    'iname': ['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df3 = DataFrame(data3)
df3
# Out:
#     id      city  birth_year    iname
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satochi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
concat_data = pd.concat([df1,df2])
concat_data
# Out:
#     id      city  birth_year     name  math  english  sex  index_num
# 0  100     Tokyo      1990.0  Hiroshi   NaN      NaN  NaN        NaN
# 1  101     Osaka      1989.0    Akiko   NaN      NaN  NaN        NaN
# 2  102     Kyoto      1992.0     Yuki   NaN      NaN  NaN        NaN
# 3  103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4  104     Tpkyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5  106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 6  108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 7  110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 8  111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 9  113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN
# 0  100       NaN         NaN      NaN  50.0     90.0    M        0.0
# 1  101       NaN         NaN      NaN  43.0     30.0    F        1.0
# 2  102       NaN         NaN      NaN  33.0     20.0    F        2.0
# 3  105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 4  107       NaN         NaN      NaN  98.0     30.0    M        4.0

# %%
#6-2-3-1

hier_df = DataFrame(
    np.arange(9).reshape(3,3),
    index = [
        ['a','a','b'],
        [1,2,2]
    ],
    columns=[
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.stack()
# Out:
#           Osaka  Tokyo
# a 1 Blue      0    NaN
#     Red       2    1.0
#   2 Blue      3    NaN
#     Red       5    4.0
# b 2 Blue      6    NaN
#     Red       8    7.0

# %%
hier_df.stack().unstack()
# Out:
#     Osaka     Tokyo
#      Blue Red  Blue  Red
# a 1     0   2   NaN  1.0
#   2     3   5   NaN  4.0
# b 2     6   8   NaN  7.0

# %%
#6-2-3-2

dupli_data = DataFrame({
    'col1':[1,1,2,3,4,4,6,6],
    'col2':['a','b','b','b','c','c','b','b']
})
print('元のデータ')
dupli_data
# Out:
# 元のデータ
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
#6-2-3-3

city_map={
    'Tpkyo':'Kanto',
    'Hokkaido':'Hokkaido',
    'Osaka':'Kansai',
    'Kyoto':'Kansai'
}
city_map
# Out:
# {'Tpkyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
df1['region'] = df1['city'].map(city_map)
df1
# Out:
#     id      city  birth_year     name    region
# 0  100     Tokyo        1990  Hiroshi       NaN
# 1  101     Osaka        1989    Akiko    Kansai
# 2  102     Kyoto        1992     Yuki    Kansai
# 3  103  Hokkaido        1997   Satoru  Hokkaido
# 4  104     Tpkyo        1982   Steeve     Kanto
# 5  106     Tokyo        1991   Mituru       NaN
# 6  108     Osaka        1988      Aoi    Kansai
# 7  110     Kyoto        1990    Tarou    Kansai
# 8  111  Hokkaido        1995   Suguru  Hokkaido
# 9  113     Tokyo        1981   Mitsuo       NaN

# %%
#6-2-3-4

df1['up_two_num'] = df1['birth_year'].map(lambda x: str(x)[0:3])
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi       NaN        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tpkyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru       NaN        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo       NaN        198

# %%
#6-2-3-5

birth_year_bins = [1980,1985,1990,1995,2000]

birth_year_cut_data = pd.cut(df1.birth_year,birth_year_bins)
birth_year_cut_data
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64, right]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
pd.value_counts(birth_year_cut_data)
# Out:
# birth_year
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: count, dtype: int64

# %%
group_names = ['early1980s','lata1980s','early1990s','lata1990s']
birth_year_cut_data = pd.cut(df1.birth_year,birth_year_bins,labels=group_names)
pd.value_counts(birth_year_cut_data)
# Out:
# birth_year
# lata1980s     4
# early1990s    3
# early1980s    2
# lata1990s     1
# Name: count, dtype: int64

# %%
pd.cut(df1.birth_year, 2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: birth_year, dtype: category
# Categories (2, interval[float64, right]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
pd.value_counts(pd.qcut(df1.birth_year,2))
# Out:
# birth_year
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: count, dtype: int64

# %%
#6-2-4
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi       NaN        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tpkyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru       NaN        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo       NaN        198

# %%
df1.groupby('city').size()
# Out:
# city
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       3
# Tpkyo       1
# dtype: int64

# %%
df1.groupby(df1['city'])['birth_year'].mean()
# Out:
# city
# Hokkaido    1996.000000
# Kyoto       1991.000000
# Osaka       1988.500000
# Tokyo       1987.333333
# Tpkyo       1982.000000
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region','city'])['birth_year'].mean()
# Out:
# region    city
# Hokkaido  Hokkaido    1996.0
# Kansai    Kyoto       1991.0
#           Osaka       1988.5
# Kanto     Tpkyo       1982.0
# Name: birth_year, dtype: float64

# %%
df1.groupby(['region','city'], as_index=False)['birth_year'].mean()
# Out:
#      region      city  birth_year
# 0  Hokkaido  Hokkaido      1996.0
# 1    Kansai     Kyoto      1991.0
# 2    Kansai     Osaka      1988.5
# 3     Kanto     Tpkyo      1982.0

# %%
for group, subdf in df1.groupby('region'):
  print('==================================')
  print('Region Name:{0}'.format(group))
  print(subdf)
# Out:
# ==================================
# Region Name:Hokkaido
#     id      city  birth_year    name    region up_two_num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ==================================
# Region Name:Kansai
#     id   city  birth_year   name  region up_two_num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ==================================
# Region Name:Kanto
#     id   city  birth_year    name region up_two_num
# 4  104  Tpkyo        1982  Steeve  Kanto        198

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
student_data_math = pd.read_csv(f'/content/drive/My Drive/Colab Notebooks/student-mat.csv',sep=';')

functions = ['count','mean','max','min']
grouped_student_math_data1 = student_data_math.groupby(['sex','age'])
grouped_student_math_data1[['age','G1']].agg(functions)
# Out:
#           age                  G1
#         count  mean max min count       mean max min
# sex age
# F   15     38  15.0  15  15    38  10.052632  16   6
#     16     54  16.0  16  16    54  10.203704  16   4
#     17     58  17.0  17  17    58  11.103448  18   5
#     18     43  18.0  18  18    43  10.883721  19   5
#     19     14  19.0  19  19    14  10.642857  15   7
#     20      1  20.0  20  20     1  15.000000  15  15
# M   15     44  15.0  15  15    44  12.250000  19   5
#     16     50  16.0  16  16    50  11.740000  19   6
#     17     40  17.0  17  17    40  10.600000  17   5
#     18     39  18.0  18  18    39  10.538462  17   3
#     19     10  19.0  19  19    10   9.700000  15   5
#     20      2  20.0  20  20     2  13.000000  17   9
#     21      1  21.0  21  21     1  10.000000  10  10
#     22      1  22.0  22  22     1   6.000000   6   6

# %%
#6-3-1

import numpy as np
from numpy import nan as NA
import pandas as pd

df = pd.DataFrame(np.random.rand(10,4))

df.iloc[1,0]=NA
df.iloc[2:3,2]=NA
df.iloc[5:,3]=NA

df
# Out:
#           0         1         2         3
# 0  0.332902  0.683639  0.552838  0.689320
# 1       NaN  0.986659  0.924746  0.549933
# 2  0.329818  0.163354       NaN  0.564109
# 3  0.721541  0.471696  0.029821  0.220215
# 4  0.708772  0.809008  0.789486  0.516508
# 5  0.918214  0.026530  0.549406       NaN
# 6  0.934895  0.422954  0.652285       NaN
# 7  0.297840  0.350587  0.094226       NaN
# 8  0.468968  0.092904  0.759651       NaN
# 9  0.346106  0.508955  0.298130       NaN

# %%
#6-3-1-1

df.dropna()
# Out:
#           0         1         2         3
# 0  0.332902  0.683639  0.552838  0.689320
# 3  0.721541  0.471696  0.029821  0.220215
# 4  0.708772  0.809008  0.789486  0.516508

# %%
#6-3-1-2

df[[0,1]].dropna()
# Out:
#           0         1
# 0  0.332902  0.683639
# 2  0.329818  0.163354
# 3  0.721541  0.471696
# 4  0.708772  0.809008
# 5  0.918214  0.026530
# 6  0.934895  0.422954
# 7  0.297840  0.350587
# 8  0.468968  0.092904
# 9  0.346106  0.508955

# %%
#6-3-1-3

df.fillna(0)
# Out:
#           0         1         2         3
# 0  0.332902  0.683639  0.552838  0.689320
# 1  0.000000  0.986659  0.924746  0.549933
# 2  0.329818  0.163354  0.000000  0.564109
# 3  0.721541  0.471696  0.029821  0.220215
# 4  0.708772  0.809008  0.789486  0.516508
# 5  0.918214  0.026530  0.549406  0.000000
# 6  0.934895  0.422954  0.652285  0.000000
# 7  0.297840  0.350587  0.094226  0.000000
# 8  0.468968  0.092904  0.759651  0.000000
# 9  0.346106  0.508955  0.298130  0.000000

# %%
#6-3-1-4

df.fillna(method='ffill')
# Out:
#           0         1         2         3
# 0  0.332902  0.683639  0.552838  0.689320
# 1  0.332902  0.986659  0.924746  0.549933
# 2  0.329818  0.163354  0.924746  0.564109
# 3  0.721541  0.471696  0.029821  0.220215
# 4  0.708772  0.809008  0.789486  0.516508
# 5  0.918214  0.026530  0.549406  0.516508
# 6  0.934895  0.422954  0.652285  0.516508
# 7  0.297840  0.350587  0.094226  0.516508
# 8  0.468968  0.092904  0.759651  0.516508
# 9  0.346106  0.508955  0.298130  0.516508

# %%
#6-3-1-5

df.mean()
# Out:
# 0    0.562117
# 1    0.451629
# 2    0.516732
# 3    0.508017
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#           0         1         2         3
# 0  0.332902  0.683639  0.552838  0.689320
# 1  0.562117  0.986659  0.924746  0.549933
# 2  0.329818  0.163354  0.516732  0.564109
# 3  0.721541  0.471696  0.029821  0.220215
# 4  0.708772  0.809008  0.789486  0.516508
# 5  0.918214  0.026530  0.549406  0.508017
# 6  0.934895  0.422954  0.652285  0.508017
# 7  0.297840  0.350587  0.094226  0.508017
# 8  0.468968  0.092904  0.759651  0.508017
# 9  0.346106  0.508955  0.298130  0.508017

# %%
#6-4-1

import pandas_datareader.data as pdr

start_data='2001/1/2'
end_data='2016/12/30'

fx_jpusdata = pdr.DataReader('DEXJPUS','fred',start_data,end_data)
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
#6-4-1-1

#fx_jpusdata['２０１６−０４']
fx_jpusdata.resample('M').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
#6-4-1-2

fx_jpusdata.resample('D').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06      NaN

# %%
fx_jpusdata.resample('D').ffill().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06   116.19

# %%
#6-4-1-3

fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
fx_jpusdata_ratio = fx_jpusdata / fx_jpusdata.shift(1)
fx_jpusdata_ratio.head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03  0.995903
# 2001-01-04  1.010590
# 2001-01-05  1.006235
# 2001-01-08  0.998107

# %%
#6-4-2

fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
fx_jpusdata.rolling(3).mean().head()
# Out:
#                DEXJPUS
# DATE
# 2001-01-02         NaN
# 2001-01-03         NaN
# 2001-01-04  114.820000
# 2001-01-05  115.306667
# 2001-01-08  115.876667

# %%
fx_jpusdata.rolling(3).std().head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03       NaN
# 2001-01-04  0.610000
# 2001-01-05  0.975312
# 2001-01-08  0.368963

# %%
#総合問題6-

student_data_math = pd.read_csv(f'/content/drive/My Drive/Colab Notebooks/student-mat.csv',sep=';')

student_data_math.groupby(['age','sex'])['G1'].mean().unstack()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
# 21         NaN  10.000000
# 22         NaN   6.000000

# %%
#総合問題6-2

student_data_math.groupby(['age','sex'])['G1'].mean().unstack().dropna()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
